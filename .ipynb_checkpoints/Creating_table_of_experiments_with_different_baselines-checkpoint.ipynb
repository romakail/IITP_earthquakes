# %%
import pandas as pd

# %%
! ls
# Out:
# Article_RTLfeatures.pdf
# Data
# Experiments
# LSTM_all_experiments.xlsx
# Metric_threshold_dependency.csv
# Metric_threshold_dependency_baseline_1.csv
# Presentation.pdf
# Presentation.pptx
# README.md
# RTL_features
# Research
# Untitled.ipynb
# earthquakes_LSTM+increased_resolution.ipynb
# earthquakes_LSTM-dependencie_from_threshold.ipynb
# earthquakes_LSTM-dependencie_from_threshold_graphics.ipynb
# earthquakes_LSTM.ipynb
# earthquakes_RNN_1.ipynb
# earthquakes_RNN_2.ipynb
# earthquakes_RTL-L_R=25_3.ipynb
# earthquakes_RTL_T=20_R=25.ipynb
# earthquakes_RTL_T=20_R=50.ipynb
# earthquakes_RTL_T=45_R=100.ipynb
# earthquakes_RTL_T=90_R=100.ipynb
# earthquakes_boosting.ipynb
# earthquakes_data.csv
# earthquakes_origin.ipynb
# earthquakes_some_researches.ipynb
# earthquakes_unet.ipynb
# img
# rtl.pdf
# untitled.txt

# %%
baseline = pd.read_csv("Metric_threshold_dependency_baseline_1.csv")
results  = pd.read_csv("Metric_threshold_dependency.csv")

# %%
baseline
# Out:
#    Unnamed: 0  threshold   portion        weight  avg_prec   roc_auc  \
# 0           0        2.5  0.010068     99.320805  0.245868  0.962180
# 1           1        3.0  0.004895    204.285242  0.129070  0.959930
# 2           2        3.5  0.002041    489.943287  0.048781  0.956748
# 3           3        4.0  0.000799   1252.323645  0.015929  0.953639
# 4           4        4.5  0.000303   3301.247928  0.004710  0.948589
# 5           5        5.0  0.000110   9084.009917  0.001128  0.943966
# 6           6        5.5  0.000042  23998.661323  0.000397  0.939539
# 7           7        6.0  0.000014  69778.412112  0.000219  0.956194
#
#    F1 (0.5)  prec_rec_auc  ext_avg_prc  ext_roc_auc  ext_F1 (0.5)  \
# 0       0.0      0.247691     0.481823     0.863641           0.0
# 1       0.0      0.130487     0.449847     0.876639           0.0
# 2       0.0      0.048855     0.417433     0.897598           0.0
# 3       0.0      0.015879     0.323335     0.906983           0.0
# 4       0.0      0.004672     0.166300     0.901960           0.0
# 5       0.0      0.001084     0.059438     0.903593           0.0
# 6       0.0      0.000363     0.020439     0.910503           0.0
# 7       0.0      0.000147     0.007160     0.937934           0.0
#
#    ext_prec_rec_auc
# 0          0.504820
# 1          0.466526
# 2          0.427819
# 3          0.329302
# 4          0.169282
# 5          0.060532
# 6          0.020749
# 7          0.007186

# %%
results
# Out:
#    Unnamed: 0  Unnamed: 0.1  threshold   portion        weight   roc_auc  \
# 0           0             0        2.5  0.010068     99.320805  0.963683
# 1           1             1        3.0  0.004895    204.285242  0.957381
# 2           2             2        3.5  0.002041    489.943287  0.955360
# 3           3             3        4.0  0.000799   1252.323645  0.948742
# 4           4             4        4.5  0.000303   3301.247928  0.929893
# 5           5             5        5.0  0.000110   9084.009917  0.918044
# 6           6             6        5.5  0.000042  23998.661323  0.898686
# 7           7             7        6.0  0.000014  69778.412112  0.541425
#
#    avg_prec  F1 (0.5)  prec_rec_auc  ext_avg_prc  ext_avg_prec  ext_F1 (0.5)  \
# 0  0.264607  0.096355      0.264608     0.943969      0.759228      0.646104
# 1  0.150342  0.040910      0.150351     0.926587      0.694539      0.512605
# 2  0.071804  0.020690      0.071795     0.933231      0.670191      0.411499
# 3  0.020828  0.003589      0.020818     0.941151      0.497208      0.158036
# 4  0.005125  0.004266      0.005122     0.919128      0.243163      0.223143
# 5  0.001432  0.001061      0.001430     0.905366      0.094575      0.074309
# 6  0.000572  0.000394      0.000569     0.898028      0.034534      0.030514
# 7  0.000019  0.000045      0.000019     0.571424      0.001854      0.005136
#
#    ext_prec_rec_auc
# 0          0.759284
# 1          0.695193
# 2          0.670307
# 3          0.497450
# 4          0.243223
# 5          0.094675
# 6          0.034539
# 7          0.001868

# %%
baseline = baseline.rename(columns={"portion"  :"portion_base",
                        "weight"   :"weight_base",
                        "roc_auc"  :"roc_auc_base",
                        "avg_prec" :"avg_prec_base",
                        "F1 (0.5)" :"F1 (0.5)_base",
                        "prec_rec_auc":"prec_rec_auc_base",
                        "ext_roc_auc"  :"ext_roc_auc_base",
                        "ext_avg_prec" :"ext_avg_prec_base",
                        "ext_F1 (0.5)" :"ext_F1 (0.5)_base",
                        "ext_prec_rec_auc":"ext_prec_rec_auc_base"})

# %%
list(baseline)
# Out:
# ['Unnamed: 0',
#  'threshold',
#  'portion',
#  'weight',
#  'avg_prec',
#  'roc_auc',
#  'F1 (0.5)',
#  'prec_rec_auc',
#  'ext_avg_prc',
#  'ext_roc_auc',
#  'ext_F1 (0.5)',
#  'ext_prec_rec_auc']

# %%
baseline = baseline.drop(columns=['Unnamed: 0', 'threshold'])

# %%
baseline
# Out:
#     portion        weight  avg_prec   roc_auc  F1 (0.5)  prec_rec_auc  \
# 0  0.010068     99.320805  0.245868  0.962180       0.0      0.247691
# 1  0.004895    204.285242  0.129070  0.959930       0.0      0.130487
# 2  0.002041    489.943287  0.048781  0.956748       0.0      0.048855
# 3  0.000799   1252.323645  0.015929  0.953639       0.0      0.015879
# 4  0.000303   3301.247928  0.004710  0.948589       0.0      0.004672
# 5  0.000110   9084.009917  0.001128  0.943966       0.0      0.001084
# 6  0.000042  23998.661323  0.000397  0.939539       0.0      0.000363
# 7  0.000014  69778.412112  0.000219  0.956194       0.0      0.000147
#
#    ext_avg_prc  ext_roc_auc  ext_F1 (0.5)  ext_prec_rec_auc
# 0     0.481823     0.863641           0.0          0.504820
# 1     0.449847     0.876639           0.0          0.466526
# 2     0.417433     0.897598           0.0          0.427819
# 3     0.323335     0.906983           0.0          0.329302
# 4     0.166300     0.901960           0.0          0.169282
# 5     0.059438     0.903593           0.0          0.060532
# 6     0.020439     0.910503           0.0          0.020749
# 7     0.007160     0.937934           0.0          0.007186

# %%
baseline
# Out:
#    portion_base   weight_base  avg_prec_base  roc_auc_base  F1 (0.5)_base  \
# 0      0.010068     99.320805       0.245868      0.962180            0.0
# 1      0.004895    204.285242       0.129070      0.959930            0.0
# 2      0.002041    489.943287       0.048781      0.956748            0.0
# 3      0.000799   1252.323645       0.015929      0.953639            0.0
# 4      0.000303   3301.247928       0.004710      0.948589            0.0
# 5      0.000110   9084.009917       0.001128      0.943966            0.0
# 6      0.000042  23998.661323       0.000397      0.939539            0.0
# 7      0.000014  69778.412112       0.000219      0.956194            0.0
#
#    prec_rec_auc_base  ext_avg_prc  ext_roc_auc_base  ext_F1 (0.5)_base  \
# 0           0.247691     0.481823          0.863641                0.0
# 1           0.130487     0.449847          0.876639                0.0
# 2           0.048855     0.417433          0.897598                0.0
# 3           0.015879     0.323335          0.906983                0.0
# 4           0.004672     0.166300          0.901960                0.0
# 5           0.001084     0.059438          0.903593                0.0
# 6           0.000363     0.020439          0.910503                0.0
# 7           0.000147     0.007160          0.937934                0.0
#
#    ext_prec_rec_auc_base
# 0               0.504820
# 1               0.466526
# 2               0.427819
# 3               0.329302
# 4               0.169282
# 5               0.060532
# 6               0.020749
# 7               0.007186

# %%
results = results.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])
