# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math as m
import datetime as dt
from tqdm import tqdm_notebook as tqdm

# %matplotlib inline

# %% [markdown]
# ### посмотрим что мы имеем

# %%
data = pd.read_csv('earthquakes_data.csv', sep=',')
data
# Out:
#         year  month  date  hour  minute  seconds      lat      long  depth  \
# 0       1990      1     1     2      19    5.018  42.2734  144.8460    8.0
# 1       1990      1     1     4       4   20.026  39.9358  142.5461   30.6
# 2       1990      1     1     7      14   11.038  36.7053  141.2990   18.6
# 3       1990      1     1     9       3   12.039  36.4859  140.6964   67.2
# 4       1990      1     1    12      31   25.018  35.0121  138.1440   22.6
# 5       1990      1     1    18       2   34.067  35.1802  136.5092   11.0
# 6       1990      1     1    23      52   50.070  39.8000  143.7200    0.0
# 7       1990      1     2     6      53   12.093  35.5828  141.2393   24.7
# 8       1990      1     2     9      43   46.029  42.2963  142.3826   25.1
# 9       1990      1     2    10       4   50.086  39.6835  142.9171   34.0
# 10      1990      1     2    10      40   52.080  39.6100  142.7300   20.0
# 11      1990      1     2    13      24   11.092  40.1308  142.5606   57.4
# 12      1990      1     2    13      50   38.092  42.1645  142.4484   49.0
# 13      1990      1     2    14      18   23.044  38.5041  141.7815   58.0
# 14      1990      1     2    14      22   41.090  39.5400  143.1200    0.0
# 15      1990      1     2    16      26   37.045  43.2293  146.2425   78.4
# 16      1990      1     2    16      41   31.010  39.5600  142.9200   29.0
# 17      1990      1     2    17      28   19.091  39.5444  142.3777   21.0
# 18      1990      1     2    18      48   55.058  41.3588  142.2751   51.0
# 19      1990      1     2    19      41    5.071  40.4428  141.6742  119.8
# 20      1990      1     3     0      16   18.081  35.0114  137.0009   32.0
# 21      1990      1     3     8      51   31.056  35.6450  141.3559   26.0
# 22      1990      1     3     8      52    5.018  35.5388  139.3953   24.0
# 23      1990      1     3     8      53   41.087  35.5547  141.2132   26.3
# 24      1990      1     3    12      30   42.085  36.2629  139.8494   85.6
# 25      1990      1     3    13      56   23.059  37.2261  141.7087   15.4
# 26      1990      1     4     3      21   43.019  35.6166  141.3197   28.0
# 27      1990      1     4     5      39   40.084  40.4227  142.3108   35.0
# 28      1990      1     4     5      43   21.073  40.4195  142.2302   32.0
# 29      1990      1     4     6      54    4.007  39.5454  143.6991    0.0
# ...      ...    ...   ...   ...     ...      ...      ...       ...    ...
# 247444  2016      1    14    23      22    0.000  36.7000  140.6000    0.0
# 247445  2016      1    20    21      53   41.081  43.1228  146.0084   45.1
# 247446  2016      1    20    22      14    9.022  35.0644  133.0281    0.0
# 247447  2016      1    22    16      33   49.059  35.1150  139.3486    0.0
# 247448  2016      1    22    20      34    0.000  35.0000  139.1000    0.0
# 247449  2016      1    23    15      57    0.074  43.3192  145.7213  106.6
# 247450  2016      1    23    21      33   39.057  35.7825  140.5541   55.2
# 247451  2016      1    24    15      12   58.017  35.5388  140.4958   61.7
# 247452  2016      1    24    17      13   18.083  37.1964  141.1134    0.0
# 247453  2016      1    26    11      37   43.050  38.2507  141.8689   60.2
# 247454  2016      2     2     5      31   45.066  39.6272  142.8499    0.0
# 247455  2016      2     4    22      41   46.030  35.5222  139.4190   34.0
# 247456  2016      2     7     1       9   53.090  36.7051  140.3515   53.1
# 247457  2016      2     7    10      26   56.034  36.0114  139.8516   48.2
# 247458  2016      2     7    16       3   34.021  37.1015  140.7008    0.0
# 247459  2016      2     8    16      54   30.000  38.0712  141.9320   64.9
# 247460  2016      2    14    10       3   41.057  39.8190  139.3038   41.8
# 247461  2016      2    20     1      33    0.000  35.2000  139.1000    0.0
# 247462  2016      2    22    18      41    7.071  43.0638  145.6480   54.6
# 247463  2016      2    24     3      15   49.085  36.6120  140.5815   63.9
# 247464  2016      2    24    16      10   51.033  38.2991  141.8308   48.3
# 247465  2016      3     7     7      37    3.080  40.2000  142.4500   53.0
# 247466  2016      3     8     4      32    0.000  42.1000  142.9000    0.0
# 247467  2016      3    16    16      15   13.000  40.9500  142.1900   80.0
# 247468  2016      3    17    18      59   23.020  39.4800  142.3400   59.0
# 247469  2016      3    22     5      34   23.010  36.8300  140.5200   10.0
# 247470  2016      3    24     7      57   38.010  43.2500  145.6100  109.0
# 247471  2016      3    30     5       9   59.000  42.9100  144.7900   59.0
# 247472  2016      3    31     2      48   25.000  36.0600  140.2600   70.0
# 247473  2016      4     4    10      32   32.000  39.8300  141.9000   40.0
#
#         class
# 0         2.9
# 1         3.0
# 2         2.7
# 3         4.3
# 4         2.5
# 5         2.5
# 6         3.0
# 7         2.9
# 8         3.0
# 9         3.4
# 10        2.8
# 11        4.3
# 12        2.7
# 13        2.8
# 14        3.0
# 15        4.4
# 16        3.3
# 17        2.9
# 18        3.0
# 19        4.0
# 20        2.5
# 21        2.6
# 22        2.6
# 23        4.0
# 24        4.4
# 25        3.4
# 26        2.9
# 27        3.0
# 28        2.6
# 29        3.6
# ...       ...
# 247444    3.4
# 247445    5.1
# 247446    3.9
# 247447    3.9
# 247448    3.2
# 247449    4.4
# 247450    4.6
# 247451    4.4
# 247452    4.2
# 247453    4.6
# 247454    5.7
# 247455    4.6
# 247456    4.3
# 247457    4.6
# 247458    3.8
# 247459    4.3
# 247460    3.6
# 247461    3.1
# 247462    4.5
# 247463    3.6
# 247464    4.5
# 247465    4.8
# 247466    3.8
# 247467    4.2
# 247468    4.6
# 247469    4.7
# 247470    4.2
# 247471    4.7
# 247472    4.3
# 247473    4.3
#
# [247474 rows x 10 columns]

# %%
fig = plt.figure(figsize=(10.5 * m.cos(40 * m.pi / 180), 9))

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

axes.scatter(data['long'], data['lat'], color='red', marker='.', s=20)
plt.axis([120.0, 155.0, 20.0, 50.0])

axes.set_xlabel('long')
axes.set_ylabel('lat')
axes.set_title('title')

plt.show()

# %% [markdown]
# ### Спроецируем Японию на плоскость

# %%
R_polus   = 6356.86
R_ekvator = 6378.20

def local_radius (longitude):
    return m.cos (longitude * m.pi / 180) * (R_ekvator - R_polus) + R_polus

R_japan = local_radius (37)

# %%
ORIGIN_LATITUDE  = 27.0
ORIGIN_LONGITUDE = 127.0

def spherical_to_cartesian (longitude, latitude):
    X = (longitude - ORIGIN_LONGITUDE) * m.pi / 180 * R_japan * m.cos (latitude * m.pi / 180)
    Y = (latitude  - ORIGIN_LATITUDE ) * m.pi / 180 * R_japan 
    
    return X, Y

data.shape
# Out:
# (247474, 10)

# %%
XY_massive = np.zeros((data.shape[0], 2))
j = 0
for i in tqdm(range (XY_massive.shape[0])):
    XY_massive[i][0], XY_massive[i][1] = spherical_to_cartesian (data['long'][i], data['lat'][i])

data['x'] = XY_massive[:, 0]
data['y'] = XY_massive[:, 1]
#data['lat'], data['long'] = spherical_to_cartesian (data['lat'], data['long'])
# Out:
# HBox(children=(IntProgress(value=0, max=247474), HTML(value='')))

# %% [markdown]
# #### Посмотрим что получилось

# %%
fig = plt.figure(figsize=(10, 10))

axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])

axes.scatter(data['x'], data['y'], color='red', marker='.', s=20)
plt.axis([0, 2000, 0, 2500])

axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')

plt.show()

# %%
a = np.zeros(10, dtype=int)
for i in tqdm(range (data.shape[0])):
    for threshold in range (10):
        if (data['class'][i] >= threshold) and (data['class'][i] < threshold + 1):
            a[threshold] += 1
            break

            
# print ((a / data.shape[0] * 100).int())
# Out:
# HBox(children=(IntProgress(value=0, max=247474), HTML(value='')))

# %% [markdown]
# #### Распечатаем сколько землетрясений и с какой амплитудой случалось

# %%
for i in range (a.shape[0]):
    print ('from i ', i, ' to ', i+1, ' : %.3f' % (a[i]/data.shape[0]), '% of dots')
# Out:
# from i  0  to  1  : 0.000 % of dots
# from i  1  to  2  : 0.000 % of dots
# from i  2  to  3  : 0.510 % of dots
# from i  3  to  4  : 0.419 % of dots
# from i  4  to  5  : 0.061 % of dots
# from i  5  to  6  : 0.008 % of dots
# from i  6  to  7  : 0.001 % of dots
# from i  7  to  8  : 0.000 % of dots
# from i  8  to  9  : 0.000 % of dots
# from i  9  to  10  : 0.000 % of dots

# %% [markdown]
# #### Посчитаем сколько дней прошло с 01.01.1990 до i-го землетрясения

# %%
time_massive = np.zeros (data.shape[0])

d_0 = dt.date (data['year'][0], data['month'][0], data['date'][0])
for i in tqdm(range (data.shape[0])):
    d_i = dt.date (data['year'][i], data['month'][i], data['date'][i])
    time_massive[i] = (d_i - d_0).days
    
data['time'] = time_massive
# Out:
# HBox(children=(IntProgress(value=0, max=247474), HTML(value='')))

# %% [markdown]
# #### Посмотрим что имеем

# %%
data
# Out:
#         year  month  date  hour  minute  seconds      lat      long  depth  \
# 0       1990      1     1     2      19    5.018  42.2734  144.8460    8.0
# 1       1990      1     1     4       4   20.026  39.9358  142.5461   30.6
# 2       1990      1     1     7      14   11.038  36.7053  141.2990   18.6
# 3       1990      1     1     9       3   12.039  36.4859  140.6964   67.2
# 4       1990      1     1    12      31   25.018  35.0121  138.1440   22.6
# 5       1990      1     1    18       2   34.067  35.1802  136.5092   11.0
# 6       1990      1     1    23      52   50.070  39.8000  143.7200    0.0
# 7       1990      1     2     6      53   12.093  35.5828  141.2393   24.7
# 8       1990      1     2     9      43   46.029  42.2963  142.3826   25.1
# 9       1990      1     2    10       4   50.086  39.6835  142.9171   34.0
# 10      1990      1     2    10      40   52.080  39.6100  142.7300   20.0
# 11      1990      1     2    13      24   11.092  40.1308  142.5606   57.4
# 12      1990      1     2    13      50   38.092  42.1645  142.4484   49.0
# 13      1990      1     2    14      18   23.044  38.5041  141.7815   58.0
# 14      1990      1     2    14      22   41.090  39.5400  143.1200    0.0
# 15      1990      1     2    16      26   37.045  43.2293  146.2425   78.4
# 16      1990      1     2    16      41   31.010  39.5600  142.9200   29.0
# 17      1990      1     2    17      28   19.091  39.5444  142.3777   21.0
# 18      1990      1     2    18      48   55.058  41.3588  142.2751   51.0
# 19      1990      1     2    19      41    5.071  40.4428  141.6742  119.8
# 20      1990      1     3     0      16   18.081  35.0114  137.0009   32.0
# 21      1990      1     3     8      51   31.056  35.6450  141.3559   26.0
# 22      1990      1     3     8      52    5.018  35.5388  139.3953   24.0
# 23      1990      1     3     8      53   41.087  35.5547  141.2132   26.3
# 24      1990      1     3    12      30   42.085  36.2629  139.8494   85.6
# 25      1990      1     3    13      56   23.059  37.2261  141.7087   15.4
# 26      1990      1     4     3      21   43.019  35.6166  141.3197   28.0
# 27      1990      1     4     5      39   40.084  40.4227  142.3108   35.0
# 28      1990      1     4     5      43   21.073  40.4195  142.2302   32.0
# 29      1990      1     4     6      54    4.007  39.5454  143.6991    0.0
# ...      ...    ...   ...   ...     ...      ...      ...       ...    ...
# 247444  2016      1    14    23      22    0.000  36.7000  140.6000    0.0
# 247445  2016      1    20    21      53   41.081  43.1228  146.0084   45.1
# 247446  2016      1    20    22      14    9.022  35.0644  133.0281    0.0
# 247447  2016      1    22    16      33   49.059  35.1150  139.3486    0.0
# 247448  2016      1    22    20      34    0.000  35.0000  139.1000    0.0
# 247449  2016      1    23    15      57    0.074  43.3192  145.7213  106.6
# 247450  2016      1    23    21      33   39.057  35.7825  140.5541   55.2
# 247451  2016      1    24    15      12   58.017  35.5388  140.4958   61.7
# 247452  2016      1    24    17      13   18.083  37.1964  141.1134    0.0
# 247453  2016      1    26    11      37   43.050  38.2507  141.8689   60.2
# 247454  2016      2     2     5      31   45.066  39.6272  142.8499    0.0
# 247455  2016      2     4    22      41   46.030  35.5222  139.4190   34.0
# 247456  2016      2     7     1       9   53.090  36.7051  140.3515   53.1
# 247457  2016      2     7    10      26   56.034  36.0114  139.8516   48.2
# 247458  2016      2     7    16       3   34.021  37.1015  140.7008    0.0
# 247459  2016      2     8    16      54   30.000  38.0712  141.9320   64.9
# 247460  2016      2    14    10       3   41.057  39.8190  139.3038   41.8
# 247461  2016      2    20     1      33    0.000  35.2000  139.1000    0.0
# 247462  2016      2    22    18      41    7.071  43.0638  145.6480   54.6
# 247463  2016      2    24     3      15   49.085  36.6120  140.5815   63.9
# 247464  2016      2    24    16      10   51.033  38.2991  141.8308   48.3
# 247465  2016      3     7     7      37    3.080  40.2000  142.4500   53.0
# 247466  2016      3     8     4      32    0.000  42.1000  142.9000    0.0
# 247467  2016      3    16    16      15   13.000  40.9500  142.1900   80.0
# 247468  2016      3    17    18      59   23.020  39.4800  142.3400   59.0
# 247469  2016      3    22     5      34   23.010  36.8300  140.5200   10.0
# 247470  2016      3    24     7      57   38.010  43.2500  145.6100  109.0
# 247471  2016      3    30     5       9   59.000  42.9100  144.7900   59.0
# 247472  2016      3    31     2      48   25.000  36.0600  140.2600   70.0
# 247473  2016      4     4    10      32   32.000  39.8300  141.9000   40.0
#
#         class            x            y    time
# 0         2.9  1469.001496  1699.098417     0.0
# 1         3.0  1326.068924  1439.050722     0.0
# 2         2.7  1275.297146  1079.671839     0.0
# 3         4.3  1225.030854  1055.264556     0.0
# 4         2.5  1015.369695   891.310804     0.0
# 5         2.5   864.632781   910.011188     0.0
# 6         3.0  1429.027552  1423.943571     0.0
# 7         2.9  1288.276622   954.798663     1.0
# 8         3.0  1265.765445  1701.645941     1.0
# 9         3.4  1362.707004  1410.983460     1.0
# 10        2.8  1348.121150  1402.806909     1.0
# 11        4.3  1323.516200  1460.743613     1.0
# 12        2.7  1273.836895  1686.983772     1.0
# 13        2.8  1286.829373  1279.780409     1.0
# 14        3.0  1382.941439  1395.019717     1.0
# 15        4.4  1559.712236  1805.438078     1.0
# 16        3.3  1365.389713  1397.244629     1.0
# 17        2.9  1319.175578  1395.509198     1.0
# 18        3.0  1275.462128  1597.353199     1.0
# 19        4.0  1242.374953  1495.452237     1.0
# 20        2.5   911.225565   891.232932     2.0
# 21        2.6  1297.816225   961.718138     2.0
# 22        2.6  1122.059678   949.903857     2.0
# 23        4.0  1286.366337   951.672662     2.0
# 24        4.4  1152.573119  1030.456789     2.0
# 25        3.4  1302.893618  1137.608543     2.0
# 26        2.9  1295.003632   958.558764     3.0
# 27        3.0  1296.659516  1493.216201     3.0
# 28        2.6  1289.894922  1492.860215     3.0
# 29        3.6  1432.511199  1395.620443     3.0
# ...       ...          ...          ...     ...
# 247444    3.4  1213.038479  1079.082237  9509.0
# 247445    5.1  1543.426583  1793.590422  9515.0
# 247446    3.9   548.890313   897.128948  9515.0
# 247447    3.9  1123.707777   902.757975  9517.0
# 247448    3.2  1102.637350   889.964732  9517.0
# 247449    4.4  1515.226012  1815.439057  9518.0
# 247450    4.6  1223.218839   977.014407  9518.0
# 247451    4.4  1221.680234   949.903857  9519.0
# 247452    4.2  1250.654251  1134.304549  9519.0
# 247453    4.6  1298.979891  1251.590776  9521.0
# 247454    5.7  1358.059507  1404.720333  9528.0
# 247455    4.6  1124.437685   948.057180  9530.0
# 247456    4.3  1190.794752  1079.649590  9533.0
# 247457    4.6  1156.471301  1002.478523  9533.0
# 247458    3.8  1215.616347  1123.747342  9533.0
# 247459    4.3  1307.707893  1231.622192  9534.0
# 247460    3.6  1051.292487  1426.057237  9540.0
# 247461    3.1  1099.935587   912.213850  9546.0
# 247462    4.5  1515.622591  1787.026933  9548.0
# 247463    3.6  1212.773778  1069.292625  9550.0
# 247464    4.5  1294.788082  1256.975063  9550.0
# 247465    4.8  1312.770138  1468.441808  9562.0
# 247466    3.8  1312.410507  1679.808431  9563.0
# 247467    4.2  1276.290716  1551.876001  9571.0
# 247468    4.6  1317.161862  1388.344982  9572.0
# 247469    4.7  1203.860425  1093.544164  9577.0
# 247470    4.2  1507.932185  1807.740862  9579.0
# 247471    4.7  1449.510519  1769.917361  9585.0
# 247472    4.3  1192.485723  1007.885059  9586.0
# 247473    4.3  1272.919787  1427.280939  9590.0
#
# [247474 rows x 13 columns]

# %% [markdown]
# ## Разбиение датасета по дням и по клетка в сетке

# %%
import torch

# %%
LEFT_BORDER = 0
RIGHT_BORDER = 2000
DOWN_BORDER = 0
UP_BORDER = 2500

N_CELLS_HOR = 200
N_CELLS_VER = 250

print (data['time'][data.shape[0] - 1])
celled_data = torch.zeros ([int (data['time'][data.shape[0] - 1] + 1), 1, N_CELLS_HOR, N_CELLS_VER])
print (celled_data.shape)

for i in tqdm(range (data.shape[0])):
    if (data['x'][i] > LEFT_BORDER) and (data['x'][i] < RIGHT_BORDER) and (data['y'][i] > DOWN_BORDER) and (data['y'][i] < UP_BORDER):
        x = int (data['x'][i] / (RIGHT_BORDER - LEFT_BORDER) * N_CELLS_HOR)
        y = int (data['y'][i] / (UP_BORDER    - DOWN_BORDER) * N_CELLS_VER)
        celled_data[int(data['time'][i]), 0, x, y] = data['class'][i]
#         celled_data[int(data['time'][i]), 1, x, y] = data['depth'][i]
        
# celled_data
del data
# Out:
# 9590.0
# torch.Size([9591, 1, 200, 250])
# HBox(children=(IntProgress(value=0, max=247474), HTML(value='')))

# %%
print (celled_data.shape)
print (celled_data.dtype)
# Out:
# torch.Size([9591, 1, 200, 250])
# torch.float32

# %%
# OBSERVED_DAYS = 32     # 1 months
# DAYS_TO_PREDICT = 4
# STEP = 10

# train_data   = torch.zeros ([0, OBSERVED_DAYS, N_CELLS_HOR, N_CELLS_VER])
# train_result = torch.zeros ([0,             1, N_CELLS_HOR, N_CELLS_VER])
# for i in tqdm(range (OBSERVED_DAYS, celled_data.shape[0] - DAYS_TO_PREDICT, STEP)):
#     current_history = torch.zeros ([0, N_CELLS_HOR, N_CELLS_VER])
#     for rest in range (OBSERVED_DAYS):   
#         current_history = torch.cat((current_history, celled_data[i - rest - 1, :, :, :]), dim=0)
#     current_history.unsqueeze(0)
#     train_data = torch.cat((train_data, current_history), dim=0)
    
# train_data   = torch.zeros ([0, OBSERVED_DAYS, N_CELLS_HOR, N_CELLS_VER])
# train_result = torch.zeros ([0,             1, N_CELLS_HOR, N_CELLS_VER])
# for i in tqdm(range (OBSERVED_DAYS, celled_data.shape[0] - DAYS_TO_PREDICT, STEP)):
#     current_history = torch.zeros ([0, N_CELLS_HOR, N_CELLS_VER])
#     for rest in range (OBSERVED_DAYS):
#         current_history = torch.cat((current_history, celled_data[i - rest, :, :, :]), dim=0)
#     current_history = current_history.unsqueeze(0)
#     train_data = torch.cat((train_data, current_history), dim=0)

#     train_result = torch.cat ((train_result, torch.sum (celled_data[i:(i + DAYS_TO_PREDICT), :, :, :], dim=0, keepdim=True)), dim=0)

#     print ('train_data', train_data.shape)
#     print ('train_result       ', train_result.shape)

# %%
# print (train_data.shape)
# print (train_result.shape)

# %% [markdown]
# # Обучение

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import accuracy_score

# %%
DEVICE_ID = 0
DEVICE = torch.device('cuda:%d' % DEVICE_ID)
print (DEVICE)
torch.cuda.set_device(DEVICE_ID)
# Out:
# cuda:0

# %% [markdown]
# ### Создадим датасет
# #### (Может не влезть в оперативку (надо ~ 12Gb))

# %%
OBSERVED_DAYS = 32     # 1 months
DAYS_TO_PREDICT = 4
STEP = 10
TESTING_DAYS = 500

class EartquakeDataset (Dataset):
    def __init__(self, celled_data, is_train=True):
        
        self.train_data   = torch.zeros ([0, OBSERVED_DAYS, N_CELLS_HOR, N_CELLS_VER])
        self.train_result = torch.zeros ([0,             1, N_CELLS_HOR, N_CELLS_VER])
        if is_train is True:
            for i in tqdm(range (OBSERVED_DAYS, celled_data.shape[0] - DAYS_TO_PREDICT - TESTING_DAYS, STEP)):
                current_history = torch.zeros ([0, N_CELLS_HOR, N_CELLS_VER])
                for rest in range (OBSERVED_DAYS):
                    current_history = torch.cat((current_history, celled_data[i - rest, :, :, :]), dim=0)
                current_history = current_history.unsqueeze(0)
                self.train_data = torch.cat((self.train_data, current_history), dim=0)

                self.train_result = torch.cat ((self.train_result, torch.sum (celled_data[i:(i + DAYS_TO_PREDICT), :, :, :], dim=0, keepdim=True)), dim=0)
        
        else:
            for i in tqdm(range (celled_data.shape[0] - DAYS_TO_PREDICT - TESTING_DAYS, celled_data.shape[0] - DAYS_TO_PREDICT, STEP)):
                current_history = torch.zeros ([0, N_CELLS_HOR, N_CELLS_VER])
                for rest in range (OBSERVED_DAYS):
                    current_history = torch.cat((current_history, celled_data[i - rest, :, :, :]), dim=0)
                current_history = current_history.unsqueeze(0)
                self.train_data = torch.cat((self.train_data, current_history), dim=0)

                self.train_result = torch.cat ((self.train_result, torch.sum (celled_data[i:(i + DAYS_TO_PREDICT), :, :, :], dim=0, keepdim=True)), dim=0)
        
        
        
        print ('data_shape   = ', self.train_data.shape)
        print ('result_shape = ', self.train_result.shape)
        assert (self.train_data.shape[0] == self.train_result.shape[0])
        self.size = self.train_data.shape[0]
        
    def __len__ (self):
        return self.size
    
    def __getitem__(self, idx):
#         print ('data_shape = ', self.train_data[idx].shape)
#         print ('result_shape = ', self.train_result[idx].shape)
        return self.train_data[idx].unsqueeze(0), self.train_result[idx].unsqueeze(0)

# %%
earthquakes_dataset_train = EartquakeDataset (celled_data, is_train=True)

earthquakes_dataset_test  = EartquakeDataset (celled_data, is_train=False)
# Out:
# HBox(children=(IntProgress(value=0, max=906), HTML(value='')))
# data_shape   =  torch.Size([906, 32, 200, 250])
# result_shape =  torch.Size([906, 1, 200, 250])
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# data_shape   =  torch.Size([50, 32, 200, 250])
# result_shape =  torch.Size([50, 1, 200, 250])

# %%
print (earthquakes_dataset_train.train_data.shape)
print (earthquakes_dataset_test .train_result.shape)

print (earthquakes_dataset_train.train_data.dtype)
print (earthquakes_dataset_test .train_result.dtype)
# Out:
# torch.Size([906, 32, 200, 250])
# torch.Size([50, 1, 200, 250])
# torch.float32
# torch.float32

# %%
eartquakes_dataloader_train = DataLoader(earthquakes_dataset_train,
                                         batch_size=33,
                                         shuffle=True,
                                         num_workers=4)

eartquakes_dataloader_test  = DataLoader(earthquakes_dataset_test,
                                         batch_size=50,
                                         shuffle=False,
                                         num_workers=1)

# %% [markdown]
# ### Создадим саму сеть

# %%
class conv_block(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride=1, padding=1):
        super(conv_block, self).__init__()
        
        self.CONV  = nn.Conv2d(    in_channels,
                                   out_channels,
                                   kernel_size=kernel_size,
                                   stride=stride,
                                   padding=padding,
                                   bias=False)             # think about it later
        
        self.BNORM =nn.BatchNorm2d(out_channels,
                                   eps=1e-05,
                                   momentum=0.1,
                                   affine=False)
        self.RELU  = nn.ReLU ()
        
    def forward(self, x):
        #print ('sizeof(x) = ', x.size())
        #print ('sizeof(xprev) = ', xprev.size())    
        
        x = self.CONV   (x)
        x = self.BNORM  (x)
        x = self.RELU   (x)
        
        return x

# %%
class ConvNetwork (nn.Module):
    
    def __init__(self):
        super(ConvNetwork, self).__init__()
        
        self.features = nn.Sequential()
        
        self.features.add_module('conv1', conv_block(     OBSERVED_DAYS    , int (OBSERVED_DAYS/2 ), 3))
        self.features.add_module('conv2', conv_block(int (OBSERVED_DAYS/2 ), int (OBSERVED_DAYS/4 ), 3))
        self.features.add_module('conv3', conv_block(int (OBSERVED_DAYS/4 ), int (OBSERVED_DAYS/8 ), 3))
        self.features.add_module('conv4', conv_block(int (OBSERVED_DAYS/8 ), int (OBSERVED_DAYS/16), 3))
        self.features.add_module('conv5', conv_block(int (OBSERVED_DAYS/16),                      1, 3))
        
        # might be a good idea to add an extra full connected layer
        
    def forward(self, x):
#         print ('input  : ', x.shape)
        x = self.features(x)
#         print ('output : ', x.shape)
        return x

# %% [markdown]
# #### Функция тренеровки

# %%
def train_network(network, 
                  device,
                  dataloader_train,
                  dataloader_test,
                  epochs=164,
                  learning_rate=0.1):
    
    train_acc = []
    net = network.to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.SGD(network.parameters(), lr=learning_rate, weight_decay=0.0001, momentum=0.9)

    
    for epoch in tqdm(range(epochs)):  # loop over the dataset multiple times
        if epoch == epochs/2:
            optimizer = torch.optim.SGD(network.parameters(), lr=learning_rate/10, weight_decay=0.0001, momentum=0.9) 
        elif epoch == epochs*3/4:
            optimizer = torch.optim.SGD(network.parameters(), lr=learning_rate/100, weight_decay=0.0001, momentum=0.9) 
        
        net = net.train()        
        epoch_accuracy = 0.0
        epoch_iters = 0
        for i, data in enumerate (dataloader_train, 0):
            
            epoch_iters += 1

            inputs = data[0].to(device)
            labels = data[1].to(device)
            print ('inputs_shape = ', inputs.shape)
            print ('labels_shape = ', labels.shape)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
#             print ('outputs : ', outputs.dtype)
#             print ('labels  : ', labels.dtype)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

#             print (loss)
            epoch_accuracy += loss.item()

        epoch_accuracy /= epoch_iters
        train_acc.append(epoch_accuracy)
        
        print('Epoch : ', epoch, 'accuracy : ', train_acc[-1])

    print('Finished Training')
    
    plt.plot(train_acc, label='Train')
    plt.legend()
    plt.grid()

# %%
earthquake_netowrk = ConvNetwork ()
train_network (earthquake_netowrk,
#                torch.device(DEVICE),
               torch.device('cpu'),
               earthquakes_dataset_train,
               earthquakes_dataset_test,
               epochs=200,
               )
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# inputs_shape =  torch.Size([1, 32, 200, 250])
# labels_shape =  torch.Size([1, 1, 200, 250])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-aba747e6e1a0> in <module>()
#       5                earthquakes_dataset_train,
#       6                earthquakes_dataset_test,
# ----> 7                epochs=200,
#       8                )
#
# <ipython-input-39-807bac94384f> in train_network(network, device, dataloader_train, dataloader_test, epochs, learning_rate)
#      35
#      36             # forward + backward + optimize
# ---> 37             outputs = net(inputs)
#      38 #             print ('outputs : ', outputs.dtype)
#      39 #             print ('labels  : ', labels.dtype)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# <ipython-input-38-77a2692968c8> in forward(self, x)
#      16     def forward(self, x):
#      17 #         print ('input  : ', x.shape)
# ---> 18         x = self.features(x)
#      19 #         print ('output : ', x.shape)
#      20         return x
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      89     def forward(self, input):
#      90         for module in self._modules.values():
# ---> 91             input = module(input)
#      92         return input
#      93
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# <ipython-input-37-745ec37f6298> in forward(self, x)
#      20         #print ('sizeof(xprev) = ', xprev.size())
#      21
# ---> 22         x = self.CONV   (x)
#      23         x = self.BNORM  (x)
#      24         x = self.RELU   (x)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     475             result = self._slow_forward(*input, **kwargs)
#     476         else:
# --> 477             result = self.forward(*input, **kwargs)
#     478         for hook in self._forward_hooks.values():
#     479             hook_result = hook(self, input, result)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     299     def forward(self, input):
#     300         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 301                         self.padding, self.dilation, self.groups)
#     302
#     303
#
# KeyboardInterrupt:

# %%
def train_network1(network, 
                  device,
                  dataloader_train,
                  dataloader_test,
                  epochs=164,
                  learning_rate=0.1):
    
    train_acc = []
    net = network.to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.SGD(network.parameters(), lr=learning_rate, weight_decay=0.0001, momentum=0.9)

    
    for epoch in tqdm(range(epochs)):  # loop over the dataset multiple times
        if epoch == epochs/2:
            optimizer = torch.optim.SGD(network.parameters(), lr=learning_rate/10, weight_decay=0.0001, momentum=0.9) 
        elif epoch == epochs*3/4:
            optimizer = torch.optim.SGD(network.parameters(), lr=learning_rate/100, weight_decay=0.0001, momentum=0.9) 
        
        net = net.train()        
        epoch_accuracy = 0.0
        epoch_iters = 0
        for item in dataloader_train:
            
            epoch_iters += 1

            inputs = item[0].to(device)
            labels = item[1].to(device)
            print ('inputs_shape = ', inputs.shape)
            print ('labels_shape = ', labels.shape)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
#             print ('outputs : ', outputs.dtype)
#             print ('labels  : ', labels.dtype)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

#             print (loss)
            epoch_accuracy_train += loss.item()

        epoch_accuracy_train /= epoch_iters
        train_acc.append(epoch_accuracy)
        
        # computing test accuracy
        for item in dataloader_test:
            inputs = item[0].to(device)
            labels = item[1].to(device)
            
        
        print('Epoch : ', epoch, 'accuracy : ', train_acc[-1])

    print('Finished Training')
    
    plt.plot(train_acc, label='Train')
    plt.legend()
    plt.grid()

# %%
class someDataset (Dataset):
    def __init__(self):
        self.data = torch.ones ([100, 32, 10, 10])
        self.len  = self.data.shape[0]
        
        
    def __len__ (self):
        return self.len
    
    def __getitem__(self, idx):
#         print ('data_shape = ', self.train_data[idx].shape)
#         print ('result_shape = ', self.train_result[idx].shape)
        return self.data[idx]

# %%
some_dataset = someDataset()
dataloader = Dataset (some_dataset,
                      torch.device('cpu'),
                      
                     )


earthquake_netowrk,
#                torch.device(DEVICE),
               torch.device('cpu'),
               earthquakes_dataset_train,
               earthquakes_dataset_test,
               epochs=200,
               )
